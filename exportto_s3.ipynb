# %% [markdown]
# # Export to S3 Function
#
# This notebook contains a function to export all files and folders from a SageMaker source directory to an S3 bucket folder.

# %%
import boto3
import os
from pathlib import Path
import logging
from botocore.exceptions import ClientError, NoCredentialsError

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
def export_directory_to_s3(bucket_name, s3_folder, source_directory, aws_access_key_id=None, aws_secret_access_key=None, region_name='us-east-1'):
    """
    Export all files and folders from a local directory to an S3 bucket folder.
    Overwrites existing files and adds new files.
    
    Args:
        bucket_name (str): Name of the S3 bucket
        s3_folder (str): Destination folder in S3 bucket
        source_directory (str): Local source directory path
        aws_access_key_id (str, optional): AWS access key ID. If None, uses default credentials
        aws_secret_access_key (str, optional): AWS secret access key. If None, uses default credentials
        region_name (str): AWS region name (default: 'us-east-1')
    
    Returns:
        bool: True if successful, False otherwise
    """
    try:
        # Create S3 client
        if aws_access_key_id and aws_secret_access_key:
            s3_client = boto3.client(
                's3',
                aws_access_key_id=aws_access_key_id,
                aws_secret_access_key=aws_secret_access_key,
                region_name=region_name
            )
        else:
            # Use default credentials (from ~/.aws/credentials, IAM role, etc.)
            s3_client = boto3.client('s3', region_name=region_name)
        
        # Ensure source directory exists
        source_path = Path(source_directory)
        if not source_path.exists():
            logger.error(f"Source directory '{source_directory}' does not exist")
            return False
        
        # Ensure s3_folder doesn't start with '/' and ends with '/'
        if s3_folder.startswith('/'):
            s3_folder = s3_folder[1:]
        if not s3_folder.endswith('/'):
            s3_folder += '/'
        
        logger.info(f"Starting upload from '{source_directory}' to 's3://{bucket_name}/{s3_folder}'")
        
        uploaded_count = 0
        
        # Walk through all files and directories in the source directory
        for root, dirs, files in os.walk(source_directory):
            # Process all files in current directory
            for file in files:
                # Get full local file path
                local_file_path = os.path.join(root, file)
                
                # Calculate relative path from source directory
                relative_path = os.path.relpath(local_file_path, source_directory)
                
                # Create S3 key (object path)
                s3_key = s3_folder + relative_path.replace('\\', '/')  # Use forward slashes for S3
                
                try:
                    # Upload file to S3
                    s3_client.upload_file(local_file_path, bucket_name, s3_key)
                    uploaded_count += 1
                    logger.info(f"Uploaded: {relative_path} -> s3://{bucket_name}/{s3_key}")
                    
                except ClientError as e:
                    logger.error(f"Error uploading {relative_path}: {e}")
                    continue
                except FileNotFoundError:
                    logger.error(f"File not found: {local_file_path}")
                    continue
        
        if uploaded_count == 0:
            logger.warning(f"No files found in directory '{source_directory}'")
        else:
            logger.info(f"Successfully uploaded {uploaded_count} files to s3://{bucket_name}/{s3_folder}")
        
        return True
        
    except NoCredentialsError:
        logger.error("AWS credentials not found. Please configure your credentials.")
        return False
    except ClientError as e:
        error_code = e.response['Error']['Code']
        if error_code == 'NoSuchBucket':
            logger.error(f"Bucket '{bucket_name}' does not exist")
        elif error_code == 'AccessDenied':
            logger.error(f"Access denied to bucket '{bucket_name}'. Check your permissions.")
        else:
            logger.error(f"AWS error: {e}")
        return False
    except Exception as e:
        logger.error(f"Unexpected error: {e}")
        return False

# %% [markdown]
# ## Usage Examples
#
# Here's how to use the function with your specific parameters:

# %%
# Example 1: Using your specific parameters (with default AWS credentials)
bucket_name = "hw4-qa-agent-results"
s3_folder = "results_v1"
source_directory = "/home/sagemaker-user/codespace/nlp_assignments/"

success = export_directory_to_s3(bucket_name, s3_folder, source_directory)
if success:
    print(f"Successfully exported files from {source_directory} to s3://{bucket_name}/{s3_folder}/")
else:
    print("Export failed")
# Out:
# INFO:__main__:Starting upload from '/home/sagemaker-user/codespace/nlp_assignments/' to 's3://hw4-qa-agent-results/results_v1/'
# INFO:__main__:Uploaded: .gitignore -> s3://hw4-qa-agent-results/results_v1/.gitignore
# INFO:__main__:Uploaded: README.md -> s3://hw4-qa-agent-results/results_v1/README.md
# INFO:__main__:Uploaded: requirements.txt -> s3://hw4-qa-agent-results/results_v1/requirements.txt
# INFO:__main__:Uploaded: recipes_from_around_the_world.csv -> s3://hw4-qa-agent-results/results_v1/recipes_from_around_the_world.csv
# INFO:__main__:Uploaded: exportto_s3.ipynb -> s3://hw4-qa-agent-results/results_v1/exportto_s3.ipynb
# INFO:__main__:Uploaded: Zip_file/exportto_s3.ipynb -> s3://hw4-qa-agent-results/results_v1/Zip_file/exportto_s3.ipynb
# INFO:__main__:Uploaded: Zip_file/nlpassignments.zip -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlpassignments.zip
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.gitignore -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.gitignore
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/exportto_s3.ipynb -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/exportto_s3.ipynb
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/import_from_s3.ipynb -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/import_from_s3.ipynb
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/COMMIT_EDITMSG -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/COMMIT_EDITMSG
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/FETCH_HEAD -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/FETCH_HEAD
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/HEAD -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/HEAD
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/ORIG_HEAD -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/ORIG_HEAD
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/config -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/config
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/description -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/description
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/index -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/index
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/hooks/applypatch-msg.sample -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/hooks/applypatch-msg.sample
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/hooks/commit-msg.sample -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/hooks/commit-msg.sample
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/hooks/fsmonitor-watchman.sample -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/hooks/fsmonitor-watchman.sample
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/hooks/post-update.sample -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/hooks/post-update.sample
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/hooks/pre-applypatch.sample -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/hooks/pre-applypatch.sample
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/hooks/pre-commit.sample -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/hooks/pre-commit.sample
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/hooks/pre-merge-commit.sample -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/hooks/pre-merge-commit.sample
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/hooks/pre-push.sample -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/hooks/pre-push.sample
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/hooks/pre-rebase.sample -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/hooks/pre-rebase.sample
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/hooks/pre-receive.sample -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/hooks/pre-receive.sample
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/hooks/prepare-commit-msg.sample -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/hooks/prepare-commit-msg.sample
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/hooks/push-to-checkout.sample -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/hooks/push-to-checkout.sample
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/hooks/update.sample -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/hooks/update.sample
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/info/exclude -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/info/exclude
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/logs/HEAD -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/logs/HEAD
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/logs/refs/heads/dalton -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/logs/refs/heads/dalton
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/logs/refs/heads/main -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/logs/refs/heads/main
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/logs/refs/heads/optimized -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/logs/refs/heads/optimized
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/logs/refs/remotes/origin/main -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/logs/refs/remotes/origin/main
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/logs/refs/remotes/origin/optimized -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/logs/refs/remotes/origin/optimized
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/objects/01/af476009b3887a355d03c032127ad27d85925d -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/objects/01/af476009b3887a355d03c032127ad27d85925d
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/objects/06/0a93f046e537f26c7e09d4dc1ac97213e4ab31 -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/objects/06/0a93f046e537f26c7e09d4dc1ac97213e4ab31
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/objects/07/1388203f35f9acdc940ff1e56daa194577cdc3 -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/objects/07/1388203f35f9acdc940ff1e56daa194577cdc3
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/objects/08/6547ae5cb9bf97019b1d23e648310c40702c84 -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/objects/08/6547ae5cb9bf97019b1d23e648310c40702c84
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/objects/0a/3a6689f09cd821392f15f14550543619dfdc04 -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/objects/0a/3a6689f09cd821392f15f14550543619dfdc04
# INFO:__main__:Uploaded: Zip_file/nlp_assignments/.git/objects/0e/31b57d6f3f905837e6c711ed51b4c7e9868c0e -> s3://hw4-qa-agent-results/results_v1/Zip_file/nlp_assignments/.git/objects
# INFO:__main__:Uploaded: .git/logs/HEAD -> s3://hw4-qa-agent-results/results_v1/.git/logs/HEAD
# INFO:__main__:Uploaded: .git/logs/refs/heads/main -> s3://hw4-qa-agent-results/results_v1/.git/logs/refs/heads/main
# INFO:__main__:Uploaded: .git/logs/refs/remotes/origin/main -> s3://hw4-qa-agent-results/results_v1/.git/logs/refs/remotes/origin/main
# INFO:__main__:Uploaded: improved_qa_agents/.gitignore -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/.gitignore
# INFO:__main__:Uploaded: improved_qa_agents/build_index.py -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/build_index.py
# INFO:__main__:Uploaded: improved_qa_agents/countries_with_languages.tsv -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/countries_with_languages.tsv
# INFO:__main__:Uploaded: improved_qa_agents/example.jsonl -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/example.jsonl
# INFO:__main__:Uploaded: improved_qa_agents/example_output.txt -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/example_output.txt
# INFO:__main__:Uploaded: improved_qa_agents/hw4_handout.pdf -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/hw4_handout.pdf
# INFO:__main__:Uploaded: improved_qa_agents/import_from_s3.ipynb -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/import_from_s3.ipynb
# INFO:__main__:Uploaded: improved_qa_agents/private.jsonl -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/private.jsonl
# INFO:__main__:Uploaded: improved_qa_agents/public.jsonl -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/public.jsonl
# INFO:__main__:Uploaded: improved_qa_agents/test.json -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/test.json
# INFO:__main__:Uploaded: improved_qa_agents/react_public.txt -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/react_public.txt
# INFO:__main__:Uploaded: improved_qa_agents/before_gpt5_public.txt -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/before_gpt5_public.txt
# INFO:__main__:Uploaded: improved_qa_agents/public.txt -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/public.txt
# INFO:__main__:Uploaded: improved_qa_agents/HW4_improved.ipynb -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/HW4_improved.ipynb
# INFO:__main__:Uploaded: improved_qa_agents/HW4_improved2.ipynb -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/HW4_improved2.ipynb
# INFO:__main__:Uploaded: improved_qa_agents/private.txt -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/private.txt
# INFO:__main__:Uploaded: improved_qa_agents/.vscode/settings.json -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/.vscode/settings.json
# INFO:__main__:Uploaded: improved_qa_agents/data/recipes.csv -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/data/recipes.csv
# INFO:__main__:Uploaded: improved_qa_agents/data/train.json -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/data/train.json
# INFO:__main__:Uploaded: improved_qa_agents/data/recipes2.csv -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/data/recipes2.csv
# INFO:__main__:Uploaded: improved_qa_agents/data/recipes_from_around_the_world.csv -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/data/recipes_from_around_the_world.csv
# INFO:__main__:Uploaded: improved_qa_agents/models/faiss_index/index.faiss -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/models/faiss_index/index.faiss
# INFO:__main__:Uploaded: improved_qa_agents/models/faiss_index/index.pkl -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/models/faiss_index/index.pkl
# INFO:__main__:Uploaded: improved_qa_agents/rag_system/_init_.py -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/rag_system/_init_.py
# INFO:__main__:Uploaded: improved_qa_agents/rag_system/rag_pipeline.py -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/rag_system/rag_pipeline.py
# INFO:__main__:Uploaded: improved_qa_agents/rag_system/tools.py -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/rag_system/tools.py
# INFO:__main__:Uploaded: improved_qa_agents/rag_system/__pycache__/rag_pipeline.cpython-312.pyc -> s3://hw4-qa-agent-results/results_v1/improved_qa_agents/rag_system/__pycache__/rag_pipeline.cpython-312.pyc
# INFO:__main__:Uploaded: baseline_qa_agents/HW4_baseline.ipynb -> s3://hw4-qa-agent-results/results_v1/baseline_qa_agents/HW4_baseline.ipynb
# INFO:__main__:Uploaded: baseline_qa_agents/countries_with_languages.tsv -> s3://hw4-qa-agent-results/results_v1/baseline_qa_agents/countries_with_languages.tsv
# INFO:__main__:Uploaded: baseline_qa_agents/example.jsonl -> s3://hw4-qa-agent-results/results_v1/baseline_qa_agents/example.jsonl
# INFO:__main__:Uploaded: baseline_qa_agents/example_output.txt -> s3://hw4-qa-agent-results/results_v1/baseline_qa_agents/example_output.txt
# INFO:__main__:Uploaded: baseline_qa_agents/hw4_handout.pdf -> s3://hw4-qa-agent-results/results_v1/baseline_qa_agents/hw4_handout.pdf
# INFO:__main__:Uploaded: baseline_qa_agents/private.jsonl -> s3://hw4-qa-agent-results/results_v1/baseline_qa_agents/private.jsonl
# INFO:__main__:Uploaded: baseline_qa_agents/public.jsonl -> s3://hw4-qa-agent-results/results_v1/baseline_qa_agents/public.jsonl
# INFO:__main__:Uploaded: baseline_qa_agents/private.txt -> s3://hw4-qa-agent-results/results_v1/baseline_qa_agents/private.txt
# INFO:__main__:Uploaded: baseline_qa_agents/public.txt -> s3://hw4-qa-agent-results/results_v1/baseline_qa_agents/public.txt
# INFO:__main__:Uploaded: baseline_qa_agents/.vscode/settings.json -> s3://hw4-qa-agent-results/results_v1/baseline_qa_agents/.vscode/settings.json
# INFO:__main__:Successfully uploaded 721 files to s3://hw4-qa-agent-results/results_v1/
# Successfully exported files from /home/sagemaker-user/codespace/nlp_assignments/ to s3://hw4-qa-agent-results/results_v1/

# %%
# # Example 2: Using explicit credentials (if needed)
# bucket_name = "sagemaker-studio-940544301691-64iyil0o5a"
# s3_folder = "nlp_assignment"
# source_directory = "/home/sagemaker-user/codespace/nlp_assignments"
# access_key = "YOUR_ACCESS_KEY_ID"  # Replace with your access key
# secret_key = "YOUR_SECRET_ACCESS_KEY"  # Replace with your secret key

# success = export_directory_to_s3(
#     bucket_name=bucket_name,
#     s3_folder=s3_folder,
#     source_directory=source_directory,
#     aws_access_key_id=access_key,
#     aws_secret_access_key=secret_key,
#     region_name='us-east-1'  # Adjust region if needed
# )

# if success:
#     print(f"Successfully exported files from {source_directory} to s3://{bucket_name}/{s3_folder}/")
# else:
#     print("Export failed")

# %%
# # Example 3: Quick function for your specific use case
# def export_nlp_assignments():
#     """Quick function to export your NLP assignments to S3"""
#     return export_directory_to_s3(
#         bucket_name="sagemaker-studio-940544301691-64iyil0o5a",
#         s3_folder="nlp_assignment",
#         source_directory="/home/sagemaker-user/codespace/nlp_assignments"
#     )

# # Simply call this function to export your files
# # success = export_nlp_assignments()
# # print("Export completed!" if success else "Export failed!")

# %% [markdown]
# ## Function Features
#
# - **Complete directory upload**: Uploads all files and subfolders recursively
# - **Overwrites existing files**: Files with the same name will be replaced
# - **Preserves folder structure**: Maintains the original directory structure in S3
# - **Handles large files**: Uses efficient file upload methods
# - **Error handling**: Comprehensive error handling and logging
# - **Flexible authentication**: Supports both default AWS credentials and explicit credentials
#
# ## Prerequisites
#
# 1. **AWS credentials configured** in one of these ways:
#    - IAM role (recommended for SageMaker)
#    - AWS credentials file (`~/.aws/credentials`)
#    - Environment variables (`AWS_ACCESS_KEY_ID`, `AWS_SECRET_ACCESS_KEY`)
#    - Or pass credentials directly to the function
#
# 2. **Required Python packages** (usually pre-installed in SageMaker):
#    ```bash
#    pip install boto3
#    ```
#
# 3. **S3 permissions**: Write access to the specified bucket
